# %% [markdown]
# **2023-01-10 `06-Python-APIs - Day 1 - APIs`**

# %% [markdown]
# Being able to get data from other organizations is absolutely necessary for a solid data professional.
#
# Today we are going to take a look at one of the most common ways to get data from other organizations.

# %% [markdown]
# **Objectives**
#
# * Make GET requests with the `requests` Library.
# * Manipulate JSON response to retrieve necessary values.
# * Store JSON response in python lists and dictionaries.
# * Identify and generate the type of request needed to request movies by leveraging the OMDB API documentation.

# %% [markdown]
# **Presentation**
# * [06-1-Python-API](https://ucb.bootcampcontent.com/UCB-Coding-Bootcamp/UCB-VIRT-DATA-PT-11-2022-U-LOLC/-/blob/main/slides/Data-06.1_APIs.pdf)

# %% [markdown]
# **Install**
# * [Json Formatter for Chrome](https://chrome.google.com/webstore/search/json%20formatter)

# %% [markdown]
# **API Keys**
# * Request free API Key from `OMDBAPI` [Here](https://www.omdbapi.com/apikey.aspx)
# * Create an account with NYT by filling out this [form](https://developer.nytimes.com/accounts/create).

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.01 Instructor Do: Intro to Requests (5 mins)

# %% [markdown]
# [https://jsonplaceholder.typicode.com/posts/](https://jsonplaceholder.typicode.com/posts/)

# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = "https://api.spacexdata.com/v2/launchpads"

# %%
# Print the response object to the console
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"padid":5,"id":"vafb_slc_3w","name":"VAFB SLC 3W","full_name":"Vandenberg Air Force Base Space Launch Complex 3W","status":"retired","location":{"name":"Vandenberg Air Force Base","region":"California","latitude":34.6440904,"longitude":-120.5931438},"vehicles_launched":["Falcon 1"],"attempted_launches":0,"successful_launches":0,"wikipedia":"https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3","details":"SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts."},{"padid":2,"id":"ccafs_slc_40","name":"CCAFS SLC 40","full_name":"Cape Canaveral Air Force Station Space Launch Complex 40","status":"active","location":{"name":"Cape Canaveral","region":"Florida","latitude":28.5618571,"longitude":-80.577366},"vehicles_launched":["Falcon 9"],"attempted_launches":61,"successful_launches":59,"wikipedia":"https://en.wikipedia.org/wiki/Cape_Canaveral_Air_Force_Station_Space_Launch_Complex_40","details":"SpaceX primary Falcon 9 launch pad, where all east coast Falcon 9s launched prior to the AMOS-6 anomaly. Initially used to launch Titan rockets for Lockheed Martin. Back online since CRS-13 on 2017-12-15."},{"padid":8,"id":"stls","name":"STLS","full_name":"SpaceX South Texas Launch Site","status":"under construction","location":{"name":"Boca Chica Village","region":"Texas","latitude":25.9972641,"longitude":-97.1560845},"vehicles_launched":["Falcon 9"],"attempted_launches":0,"successful_launches":0,"wikipedia":"https://en.wikipedia.org/wiki/SpaceX_South_Texas_Launch_Site","details":"SpaceX new launch site currently under construction to help keep up with the Falcon 9 and Heavy manifests. Expected to be completed in late 2018. Initially will be limited to 12 flights per year, and only GTO launches."},{"padid":1,"id":"kwajalein_atoll","name":"Kwajalein Atoll","full_name":"Kwajalein Atoll Omelek Island","status":"retired","location":{"name":"Omelek Island","region":"Marshall Islands","latitude":9.0477206,"longitude":167.7431292},"vehicles_launched":["Falcon 1"],"attempted_launches":5,"successful_launches":2,"wikipedia":"https://en.wikipedia.org/wiki/Omelek_Island","details":"SpaceX original launch site, where all of the Falcon 1 launches occured. Abandoned as SpaceX decided against upgrading the pad to support Falcon 9."},{"padid":6,"id":"vafb_slc_4e","name":"VAFB SLC 4E","full_name":"Vandenberg Air Force Base Space Launch Complex 4E","status":"active","location":{"name":"Vandenberg Air Force Base","region":"California","latitude":34.632093,"longitude":-120.610829},"vehicles_launched":["Falcon 9"],"attempted_launches":16,"successful_launches":16,"wikipedia":"https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_4","details":"SpaceX primary west coast launch pad for polar orbits and sun synchronous orbits, primarily used for Iridium. Also intended to be capable of launching Falcon Heavy."},{"padid":4,"id":"ksc_lc_39a","name":"KSC LC 39A","full_name":"Kennedy Space Center Historic Launch Complex 39A","status":"active","location":{"name":"Cape Canaveral","region":"Florida","latitude":28.6080585,"longitude":-80.6039558},"vehicles_launched":["Falcon 9","Falcon Heavy"],"attempted_launches":27,"successful_launches":26,"wikipedia":"https://en.wikipedia.org/wiki/Kennedy_Space_Center_Launch_Complex_39#Launch_Complex_39A","details":"NASA historic launch pad that launched most of the Saturn V and Space Shuttle missions. Initially for Falcon Heavy launches, it is now launching all of SpaceX east coast missions due to the damage from the AMOS-6 anomaly. After SLC-40 repairs are complete, it will be upgraded to support Falcon Heavy, a process which will take about two months. In the future it will launch commercial crew missions and the Interplanetary Transport System."}]'

# %%
# Retrieving data and converting it into JSON
print(response.json())
# Out:
# [{'padid': 5, 'id': 'vafb_slc_3w', 'name': 'VAFB SLC 3W', 'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W', 'status': 'retired', 'location': {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.6440904, 'longitude': -120.5931438}, 'vehicles_launched': ['Falcon 1'], 'attempted_launches': 0, 'successful_launches': 0, 'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3', 'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'}, {'padid': 2, 'id': 'ccafs_slc_40', 'name': 'CCAFS SLC 40', 'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40', 'status': 'active', 'location': {'name': 'Cape Canaveral', 'region': 'Florida', 'latitude': 28.5618571, 'longitude': -80.577366}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 61, 'successful_launches': 59, 'wikipedia': 'https://en.wikipedia.org/wiki/Cape_Canaveral_Air_Force_Station_Space_Launch_Complex_40', 'details': 'SpaceX primary Falcon 9 launch pad, where all east coast Falcon 9s launched prior to the AMOS-6 anomaly. Initially used to launch Titan rockets for Lockheed Martin. Back online since CRS-13 on 2017-12-15.'}, {'padid': 8, 'id': 'stls', 'name': 'STLS', 'full_name': 'SpaceX South Texas Launch Site', 'status': 'under construction', 'location': {'name': 'Boca Chica Village', 'region': 'Texas', 'latitude': 25.9972641, 'longitude': -97.1560845}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 0, 'successful_launches': 0, 'wikipedia': 'https://en.wikipedia.org/wiki/SpaceX_South_Texas_Launch_Site', 'details': 'SpaceX new launch site currently under construction to help keep up with the Falcon 9 and Heavy manifests. Expected to be completed in late 2018. Initially will be limited to 12 flights per year, and only GTO launches.'}, {'padid': 1, 'id': 'kwajalein_atoll', 'name': 'Kwajalein Atoll', 'full_name': 'Kwajalein Atoll Omelek Island', 'status': 'retired', 'location': {'name': 'Omelek Island', 'region': 'Marshall Islands', 'latitude': 9.0477206, 'longitude': 167.7431292}, 'vehicles_launched': ['Falcon 1'], 'attempted_launches': 5, 'successful_launches': 2, 'wikipedia': 'https://en.wikipedia.org/wiki/Omelek_Island', 'details': 'SpaceX original launch site, where all of the Falcon 1 launches occured. Abandoned as SpaceX decided against upgrading the pad to support Falcon 9.'}, {'padid': 6, 'id': 'vafb_slc_4e', 'name': 'VAFB SLC 4E', 'full_name': 'Vandenberg Air Force Base Space Launch Complex 4E', 'status': 'active', 'location': {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.632093, 'longitude': -120.610829}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 16, 'successful_launches': 16, 'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_4', 'details': 'SpaceX primary west coast launch pad for polar orbits and sun synchronous orbits, primarily used for Iridium. Also intended to be capable of launching Falcon Heavy.'}, {'padid': 4, 'id': 'ksc_lc_39a', 'name': 'KSC LC 39A', 'full_name': 'Kennedy Space Center Historic Launch Complex 39A', 'status': 'active', 'location': {'name': 'Cape Canaveral', 'region': 'Florida', 'latitude': 28.6080585, 'longitude': -80.6039558}, 'vehicles_launched': ['Falcon 9', 'Falcon Heavy'], 'attempted_launches': 27, 'successful_launches': 26, 'wikipedia': 'https://en.wikipedia.org/wiki/Kennedy_Space_Center_Launch_Complex_39#Launch_Complex_39A', 'details': 'NASA historic launch pad that launched most of the Saturn V and Space Shuttle missions. Initially for Falcon Heavy launches, it is now launching all of SpaceX east coast missions due to the damage from the AMOS-6 anomaly. After SLC-40 repairs are complete, it will be upgraded to support Falcon Heavy, a process which will take about two months. In the future it will launch commercial crew missions and the Interplanetary Transport System ...

# %%
# Pretty Print the output of the JSON
ret = response.json()
# print(json.dumps(ret, indent=4, sort_keys=True))
print(json.dumps(ret, indent=4))
# ret[0]["location"]["latitude"]
# Out:
# [
#     {
#         "padid": 5,
#         "id": "vafb_slc_3w",
#         "name": "VAFB SLC 3W",
#         "full_name": "Vandenberg Air Force Base Space Launch Complex 3W",
#         "status": "retired",
#         "location": {
#             "name": "Vandenberg Air Force Base",
#             "region": "California",
#             "latitude": 34.6440904,
#             "longitude": -120.5931438
#         },
#         "vehicles_launched": [
#             "Falcon 1"
#         ],
#         "attempted_launches": 0,
#         "successful_launches": 0,
#         "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3",
#         "details": "SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts."
#     },
#     {
#         "padid": 2,
#         "id": "ccafs_slc_40",
#         "name": "CCAFS SLC 40",
#         "full_name": "Cape Canaveral Air Force Station Space Launch Complex 40",
#         "status": "active",
#         "location": {
#             "name": "Cape Canaveral",
#             "region": "Florida",
#             "latitude": 28.5618571,
#             "longitude": -80.577366
#         },
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "attempted_launches": 61,
#         "successful_launches": 59,
#         "wikipedia": "https://en.wikipedia.org/wiki/Cape_Canaveral_Air_Force_Station_Space_Launch_Complex_40",
#         "details": "SpaceX primary Falcon 9 launch pad, where all east coast Falcon 9s launched prior to the AMOS-6 anomaly. Initially used to launch Titan rockets for Lockheed Martin. Back online since CRS-13 on 2017-12-15."
#     },
#     {
#         "padid": 8,
#         "id": "stls",
#         "name": "STLS",
#         "full_name": "SpaceX South Texas Launch Site",
#         "status": "under construction",
#         "location": {
#             "name": "Boca Chica Village",
#             "region": "Texas",
#             "latitude": 25.9972641,
#             "longitude": -97.1560845
#         },
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "attempted_launches": 0,
#         "successful_launches": 0,
#         "wikipedia": "https://en.wikipedia.org/wiki/SpaceX_South_Texas_Launch_Site",
#         "details": "SpaceX new launch site currently under construction to help keep up with the Falcon 9 and Heavy manifests. Expected to be completed in late 2018. Initially will be limited to 12 flights per year, and only GTO launches."
#     },
#     {
#         "padid": 1,
#         "id": "kwajalein_atoll",
#         "name": "Kwajalein Atoll",
#         "full_name": "Kwajalein Atoll Omelek Island",
#         "status": "retired",
#         "location": {
#             "name": "Omelek Island",
#             "region": "Marshall Islands",
#             "latitude": 9.0477206,
#             "longitude": 167.7431292
#         },
#         "vehicles_launched": [
#             "Falcon 1"
#         ],
#         "attempted_launches": 5,
#         "successful_launches": 2,
#         "wikipedia": "https://en.wikipedia.org/wiki/Omelek_Island",
#         "details": "SpaceX original launch site, where all of the Falcon 1 launches occured. Abandoned as SpaceX decided against upgrading the pad to support Falcon 9."
#     },
#     {
#         "padid": 6,
#         "id": "vafb_slc_4e",
#         "name": "VAFB SLC 4E",
#         "full_name": "Vandenberg Air Force Base Space Launch Complex 4E",
#         "status": "active",
#         "location": {
#             "name": "Vandenberg Air Force Base",
#             "region": "California",
#             "latitude": 34.632093,
#             "longitude": -120.610829
#         },
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "attempted_launches": 16,
#         "successful_launches": 16,
#         "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_4",
#         "details": "SpaceX primary west coast launch pad for polar orbits and sun synchronous orbits, primarily used for Iridium. Also intended to be capable of launching Falcon Heavy."
#     },
#     {
#         "padid": 4,
#         "id": "ksc_lc_39a",
#         "name": "KSC LC 39A",
#         "full_name": "Kennedy Space Center Historic Launch Complex 39A",
#         "status": "active",
#         "location": {
#             "name": "Cape Canaveral",
#             "region": "Florida",
#             "latitude": 28.6080585,
#             "longitude": -80.6039558
#         },
#         "vehicles_launched": [
#             "Falcon 9",
#             "Falcon Heavy"
#         ],
#         "attempted_launches": 27,
#         "successful_launches": 26,
#         "wikipedia": "https://en.wikipedia.org/wiki/Kennedy_Space_Center_Launch_Complex_39#Launch_Complex_39A",
#         "details": "NASA historic launch pad that launched most of the Saturn V and Space Shuttle missions. Initially for Falcon Heavy launches, it is now launching all of SpaceX east coast missions due to the damage from the AMOS-6 anomaly. After SLC-40 repairs are complete, it will be upgraded to support Falcon Heavy, a process which will take about two months. In the future it will launch commercial crew missions and the Interplanetary Transport System."
#     }
# ]

# %%
for x in ret:
    print(x['full_name'])
# Out:
# Vandenberg Air Force Base Space Launch Complex 3W
# Cape Canaveral Air Force Station Space Launch Complex 40
# SpaceX South Texas Launch Site
# Kwajalein Atoll Omelek Island
# Vandenberg Air Force Base Space Launch Complex 4E
# Kennedy Space Center Historic Launch Complex 39A

# %%
print(json.dumps(ret[0], indent=4))
# Out:
# {
#     "padid": 5,
#     "id": "vafb_slc_3w",
#     "name": "VAFB SLC 3W",
#     "full_name": "Vandenberg Air Force Base Space Launch Complex 3W",
#     "status": "retired",
#     "location": {
#         "name": "Vandenberg Air Force Base",
#         "region": "California",
#         "latitude": 34.6440904,
#         "longitude": -120.5931438
#     },
#     "vehicles_launched": [
#         "Falcon 1"
#     ],
#     "attempted_launches": 0,
#     "successful_launches": 0,
#     "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3",
#     "details": "SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts."
# }

# %%
ret[0]["name"], ret[0]["location"]["name"]
# Out:
# ('VAFB SLC 3W', 'Vandenberg Air Force Base')

# %%
ret[0]["location"]["latitude"], ret[0]["location"]["longitude"]
# Out:
# (34.6440904, -120.5931438)

# %%
len(ret)
# Out:
# 6

# %%
ret[0].keys()
# Out:
# dict_keys(['padid', 'id', 'name', 'full_name', 'status', 'location', 'vehicles_launched', 'attempted_launches', 'successful_launches', 'wikipedia', 'details'])

# %%
# ret[5]["details"]
for x in ret:
    if x["status"] =="active":
        print("-"*32)
        print(x["full_name"])
        print(x["status"])
        print(x["details"])
# Out:
# --------------------------------
# Cape Canaveral Air Force Station Space Launch Complex 40
# active
# SpaceX primary Falcon 9 launch pad, where all east coast Falcon 9s launched prior to the AMOS-6 anomaly. Initially used to launch Titan rockets for Lockheed Martin. Back online since CRS-13 on 2017-12-15.
# --------------------------------
# Vandenberg Air Force Base Space Launch Complex 4E
# active
# SpaceX primary west coast launch pad for polar orbits and sun synchronous orbits, primarily used for Iridium. Also intended to be capable of launching Falcon Heavy.
# --------------------------------
# Kennedy Space Center Historic Launch Complex 39A
# active
# NASA historic launch pad that launched most of the Saturn V and Space Shuttle missions. Initially for Falcon Heavy launches, it is now launching all of SpaceX east coast missions due to the damage from the AMOS-6 anomaly. After SLC-40 repairs are complete, it will be upgraded to support Falcon Heavy, a process which will take about two months. In the future it will launch commercial crew missions and the Interplanetary Transport System.

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.02 Students Do: Requesting SpaceX (10 mins)

# %% [markdown]
# # Instructions
#
# * Take a few minutes to explore the SpaceX V3 API:
#
# * [GitHub](https://github.com/r-spacex/SpaceX-API)
#
# * [API Documentation](https://documenter.getpostman.com/view/2025350/RWaEzAiG#e232e64a-58a2-4bc0-af42-eb20499425cc)
#
# * Once you understand the structure of the API and its endpoint, choose one of the endpoints and do the following:
#
#   * Retrieve and print the JSON for _all_ of the records from your chosen endpoint.
#
#   * Retrieve and print the JSON for the a _specific_ record from your chosen endpoint.

# %%
# Dependencies
import requests
from pprint import pprint
import json

# %%
# URL for GET requests to retrieve vehicle data
url = "https://api.spacexdata.com/v3/launchpads"

# %%
# Pretty print JSON for all launchpads
response = requests.get(url).json()
print(json.dumps(response[0], indent=4, sort_keys=True))
# pprint(response)
# Out:
# {
#     "attempted_launches": 0,
#     "details": "SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.",
#     "id": 5,
#     "location": {
#         "latitude": 34.6440904,
#         "longitude": -120.5931438,
#         "name": "Vandenberg Air Force Base",
#         "region": "California"
#     },
#     "name": "VAFB SLC 3W",
#     "site_id": "vafb_slc_3w",
#     "site_name_long": "Vandenberg Air Force Base Space Launch Complex 3W",
#     "status": "retired",
#     "successful_launches": 0,
#     "vehicles_launched": [
#         "Falcon 1"
#     ],
#     "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3"
# }

# %%
site_id = response[0]["site_id"]
new_url = f"{url}/{site_id}"
new_url
# Out:
# 'https://api.spacexdata.com/v3/launchpads/vafb_slc_3w'

# %%
# new_url = url + "/" + response[0]["site_id"]

# %%
# Pretty print JSON for a specific launchpad
response = requests.get(new_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "attempted_launches": 0,
#     "details": "SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.",
#     "id": 5,
#     "location": {
#         "latitude": 34.6440904,
#         "longitude": -120.5931438,
#         "name": "Vandenberg Air Force Base",
#         "region": "California"
#     },
#     "name": "VAFB SLC 3W",
#     "site_id": "vafb_slc_3w",
#     "site_name_long": "Vandenberg Air Force Base Space Launch Complex 3W",
#     "status": "retired",
#     "successful_launches": 0,
#     "vehicles_launched": [
#         "Falcon 1"
#     ],
#     "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3"
# }

# %%
for x in response:
    print(x, ":", response[x])
# Out:
# id : 5
# name : VAFB SLC 3W
# status : retired
# location : {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.6440904, 'longitude': -120.5931438}
# vehicles_launched : ['Falcon 1']
# attempted_launches : 0
# successful_launches : 0
# wikipedia : https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3
# details : SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.
# site_id : vafb_slc_3w
# site_name_long : Vandenberg Air Force Base Space Launch Complex 3W

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.03 Instructor Do: Manipulating Responses (5 mins)

# %%
# Dependencies
import requests
import json
from pprint import pprint

# %%
# Performing a GET Request and saving the 
# API's response within a variable
url = "https://api.spacexdata.com/v2/rockets/falcon9"
response = requests.get(url)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "active": true,
#     "boosters": 0,
#     "company": "SpaceX",
#     "cost_per_launch": 50000000,
#     "country": "United States",
#     "description": "Falcon 9 is a two-stage rocket designed and manufactured by SpaceX for the reliable and safe transport of satellites and the Dragon spacecraft into orbit.",
#     "diameter": {
#         "feet": 12,
#         "meters": 3.7
#     },
#     "engines": {
#         "engine_loss_max": 2,
#         "isp": {
#             "sea_level": 288,
#             "vacuum": 312
#         },
#         "layout": "octaweb",
#         "number": 9,
#         "propellant_1": "liquid oxygen",
#         "propellant_2": "RP-1 kerosene",
#         "thrust_sea_level": {
#             "kN": 845,
#             "lbf": 190000
#         },
#         "thrust_to_weight": 180.1,
#         "thrust_vacuum": {
#             "kN": 914,
#             "lbf": 205500
#         },
#         "type": "merlin",
#         "version": "1D+"
#     },
#     "first_flight": "2010-06-04",
#     "first_stage": {
#         "burn_time_sec": 162,
#         "engines": 9,
#         "fuel_amount_tons": 385,
#         "reusable": true,
#         "thrust_sea_level": {
#             "kN": 7607,
#             "lbf": 1710000
#         },
#         "thrust_vacuum": {
#             "kN": 8227,
#             "lbf": 1849500
#         }
#     },
#     "flickr_images": [
#         "https://farm1.staticflickr.com/929/28787338307_3453a11a77_b.jpg",
#         "https://farm4.staticflickr.com/3955/32915197674_eee74d81bb_b.jpg",
#         "https://farm1.staticflickr.com/293/32312415025_6841e30bf1_b.jpg",
#         "https://farm1.staticflickr.com/623/23660653516_5b6cb301d1_b.jpg",
#         "https://farm6.staticflickr.com/5518/31579784413_d853331601_b.jpg",
#         "https://farm1.staticflickr.com/745/32394687645_a9c54a34ef_b.jpg"
#     ],
#     "height": {
#         "feet": 229.6,
#         "meters": 70
#     },
#     "id": "falcon9",
#     "landing_legs": {
#         "material": "carbon fiber",
#         "number": 4
#     },
#     "mass": {
#         "kg": 549054,
#         "lb": 1207920
#     },
#     "name": "Falcon 9",
#     "payload_weights": [
#         {
#             "id": "leo",
#             "kg": 22800,
#             "lb": 50265,
#             "name": "Low Earth Orbit"
#         },
#         {
#             "id": "gto",
#             "kg": 8300,
#             "lb": 18300,
#             "name": "Geosynchronous Transfer Orbit"
#         },
#         {
#             "id": "mars",
#             "kg": 4020,
#             "lb": 8860,
#             "name": "Mars Orbit"
#         }
#     ],
#     "rocketid": 2,
#     "second_stage": {
#         "burn_time_sec": 397,
#         "engines": 1,
#         "fuel_amount_tons": 90,
#         "payloads": {
#             "composite_fairing": {
#                 "diameter": {
#                     "feet": 17.1,
#                     "meters": 5.2
#                 },
#                 "height": {
#                     "feet": 43,
#                     "meters": 13.1
#                 }
#             },
#             "option_1": "dragon",
#             "option_2": "composite fairing"
#         },
#         "reusable": false,
#         "thrust": {
#             "kN": 934,
#             "lbf": 210000
#         }
#     },
#     "stages": 2,
#     "success_rate_pct": 97,
#     "type": "rocket",
#     "wikipedia": "https://en.wikipedia.org/wiki/Falcon_9"
# }

# %%
print("\n".join(response_json["flickr_images"]))
# Out:
# https://farm1.staticflickr.com/929/28787338307_3453a11a77_b.jpg
# https://farm4.staticflickr.com/3955/32915197674_eee74d81bb_b.jpg
# https://farm1.staticflickr.com/293/32312415025_6841e30bf1_b.jpg
# https://farm1.staticflickr.com/623/23660653516_5b6cb301d1_b.jpg
# https://farm6.staticflickr.com/5518/31579784413_d853331601_b.jpg
# https://farm1.staticflickr.com/745/32394687645_a9c54a34ef_b.jpg

# %%
print(f'{response_json["cost_per_launch"]:,.0f}')
# Out:
# 50,000,000

# %%
# It is possible to grab a specific value 
# from within the JSON object
print("\n".join(response_json["flickr_images"][0:-1]))
print(f'{response_json["flickr_images"][0]}')
print(f'{response_json["cost_per_launch"]:,.0f}')
# for x in response_json:
#     print(x["name"], x["cost_per_launch"])
# Out:
# https://farm1.staticflickr.com/929/28787338307_3453a11a77_b.jpg
# https://farm4.staticflickr.com/3955/32915197674_eee74d81bb_b.jpg
# https://farm1.staticflickr.com/293/32312415025_6841e30bf1_b.jpg
# https://farm1.staticflickr.com/623/23660653516_5b6cb301d1_b.jpg
# https://farm6.staticflickr.com/5518/31579784413_d853331601_b.jpg
# https://farm1.staticflickr.com/929/28787338307_3453a11a77_b.jpg
# 50,000,000

# %%
pprint(response_json["payload_weights"])
# Out:
# [{'id': 'leo', 'kg': 22800, 'lb': 50265, 'name': 'Low Earth Orbit'},
#  {'id': 'gto',
#   'kg': 8300,
#   'lb': 18300,
#   'name': 'Geosynchronous Transfer Orbit'},
#  {'id': 'mars', 'kg': 4020, 'lb': 8860, 'name': 'Mars Orbit'}]

# %%
lbs = []
for x in response_json["payload_weights"]:
    lbs.append(x["lb"])

# %%
sum(lbs)
# Out:
# 77425

# %%
# It is also possible to perform some
# analyses on values stored within the JSON object
number_payloads = len(response_json["payload_weights"])
weights = 0
weightsKG = 0
for x in response_json["payload_weights"]:
    weights += x["lb"]
    weightsKG += x["kg"]
    
print(f"There are {number_payloads} payloads. Total: {weights:,.2f} (Lbs) {weightsKG:,.2f} (KG)")
# Out:
# There are 3 payloads. Total: 77,425.00 (Lbs) 35,120.00 (KG)

# %%
# Finally, it is possible to reference the
# values stored within sub-dictionaries and sub-lists
payload_weight = response_json["payload_weights"][0]["kg"]
print(f"The first payload weighed {payload_weight:,.2f} Kilograms")
# Out:
# The first payload weighed 22,800.00 Kilograms

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.04 Students Do: Requesting a Galaxy Far Far Away (10 mins)

# %% [markdown]
# * **Instructions:**
#
#   * Using the starter file provided, collect the following pieces of information from the Star Wars API.
#
#     * The name of the character
#
#     * The number of films they were in
#
#     * The name of their first starship
#
#   * Once the data has been collected, print it out to the console.
#
# * **Hints:**
#
#   * It would be in your best interest to print out the JSON from the initial request before anything else. This will let you know what keys you should reference.
#
#   * The "starship" values are links to another API call. This means that you will need to create a request based off of the values of a previous request.
#
# * **Bonus:**
#
#   * Collect and print out all of the films a character appeared in.

# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve Star Wars character data
base_url = "https://swapi.dev/api/people/"
# Perform a get request for this character
response = requests.get(base_url).json()
# print(response.url)

# %%
response["results"][0]
# Out:
# {'name': 'Luke Skywalker',
#  'height': '172',
#  'mass': '77',
#  'hair_color': 'blond',
#  'skin_color': 'fair',
#  'eye_color': 'blue',
#  'birth_year': '19BBY',
#  'gender': 'male',
#  'homeworld': 'https://swapi.dev/api/planets/1/',
#  'films': ['https://swapi.dev/api/films/1/',
#   'https://swapi.dev/api/films/2/',
#   'https://swapi.dev/api/films/3/',
#   'https://swapi.dev/api/films/6/'],
#  'species': [],
#  'vehicles': ['https://swapi.dev/api/vehicles/14/',
#   'https://swapi.dev/api/vehicles/30/'],
#  'starships': ['https://swapi.dev/api/starships/12/',
#   'https://swapi.dev/api/starships/22/'],
#  'created': '2014-12-09T13:50:51.644000Z',
#  'edited': '2014-12-20T21:17:56.891000Z',
#  'url': 'https://swapi.dev/api/people/1/'}

# %%
for person in response["results"]:
    print("-"*64)
    print(person["name"])
    for film in person["films"]:
        film_details = requests.get(film).json()
        print("Movie:", film_details["title"])
    for vehicle in person["vehicles"]:
        vehicle_details = requests.get(vehicle).json()
        print("Vehicle:", vehicle_details["name"], "Model:", vehicle_details["model"])
# Out:
# ----------------------------------------------------------------
# Luke Skywalker
# Movie: A New Hope
# Movie: The Empire Strikes Back
# Movie: Return of the Jedi
# Movie: Revenge of the Sith
# Vehicle: Snowspeeder Model: t-47 airspeeder
# Vehicle: Imperial Speeder Bike Model: 74-Z speeder bike
# ----------------------------------------------------------------
# C-3PO
# Movie: A New Hope
# Movie: The Empire Strikes Back
# Movie: Return of the Jedi
# Movie: The Phantom Menace
# Movie: Attack of the Clones
# Movie: Revenge of the Sith
# ----------------------------------------------------------------
# R2-D2
# Movie: A New Hope
# Movie: The Empire Strikes Back
# Movie: Return of the Jedi
# Movie: The Phantom Menace
# Movie: Attack of the Clones
# Movie: Revenge of the Sith
# ----------------------------------------------------------------
# Darth Vader
# Movie: A New Hope
# Movie: The Empire Strikes Back
# Movie: Return of the Jedi
# Movie: Revenge of the Sith
# ----------------------------------------------------------------
# Leia Organa
# Movie: A New Hope
# Movie: The Empire Strikes Back
# Movie: Return of the Jedi
# Movie: Revenge of the Sith
# Vehicle: Imperial Speeder Bike Model: 74-Z speeder bike
# ----------------------------------------------------------------
# Owen Lars
# Movie: A New Hope
# Movie: Attack of the Clones
# Movie: Revenge of the Sith
# ----------------------------------------------------------------
# Beru Whitesun lars
# Movie: A New Hope
# Movie: Attack of the Clones
# Movie: Revenge of the Sith
# ----------------------------------------------------------------
# R5-D4
# Movie: A New Hope
# ----------------------------------------------------------------
# Biggs Darklighter
# Movie: A New Hope
# ----------------------------------------------------------------
# Obi-Wan Kenobi
# Movie: A New Hope
# Movie: The Empire Strikes Back
# Movie: Return of the Jedi
# Movie: The Phantom Menace
# Movie: Attack of the Clones
# Movie: Revenge of the Sith
# Vehicle: Tribubble bongo Model: Tribubble bongo

# %%
# Create a url with a specific character id
character_id = '4'
url = base_url + character_id
print(url)
# Out:
# https://swapi.dev/api/people/4

# %%
# Perform a get request for this character
response = requests.get(url)
print(response.url)
# Out:
# https://swapi.dev/api/people/4

# %%
# Storing the JSON response within a variable
data = response.json()
# Use json.dumps to print the json
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "birth_year": "41.9BBY",
#     "created": "2014-12-10T15:18:20.704000Z",
#     "edited": "2014-12-20T21:17:50.313000Z",
#     "eye_color": "yellow",
#     "films": [
#         "https://swapi.dev/api/films/1/",
#         "https://swapi.dev/api/films/2/",
#         "https://swapi.dev/api/films/3/",
#         "https://swapi.dev/api/films/6/"
#     ],
#     "gender": "male",
#     "hair_color": "none",
#     "height": "202",
#     "homeworld": "https://swapi.dev/api/planets/1/",
#     "mass": "136",
#     "name": "Darth Vader",
#     "skin_color": "white",
#     "species": [],
#     "starships": [
#         "https://swapi.dev/api/starships/13/"
#     ],
#     "url": "https://swapi.dev/api/people/4/",
#     "vehicles": []
# }

# %%
# Print the name of the character retrieved
character_name = data["name"]
print(character_name)
# Out:
# Darth Vader

# %%
# Print the number of films that they were in (hint: use len())
film_number = len(data["films"])
print(film_number)
# Out:
# 4

# %%
# Request the starships URI found in the starships property of the
# previously retreived json, then use the response to figure out what this 
# character's first starship was
first_ship_url = data["starships"][0]
ship_response = requests.get(first_ship_url).json()
ship_response
# Out:
# {'name': 'TIE Advanced x1',
#  'model': 'Twin Ion Engine Advanced x1',
#  'manufacturer': 'Sienar Fleet Systems',
#  'cost_in_credits': 'unknown',
#  'length': '9.2',
#  'max_atmosphering_speed': '1200',
#  'crew': '1',
#  'passengers': '0',
#  'cargo_capacity': '150',
#  'consumables': '5 days',
#  'hyperdrive_rating': '1.0',
#  'MGLT': '105',
#  'starship_class': 'Starfighter',
#  'pilots': ['https://swapi.dev/api/people/4/'],
#  'films': ['https://swapi.dev/api/films/1/'],
#  'created': '2014-12-12T11:21:32.991000Z',
#  'edited': '2014-12-20T21:23:49.889000Z',
#  'url': 'https://swapi.dev/api/starships/13/'}

# %%
# Print the name of the character's first starship
first_ship = ship_response["name"]
print(f"Their first ship: {first_ship}")
# Out:
# Their first ship: TIE Advanced x1

# %%
# BONUS
films = []

for film in data['films']:
    cur_film = requests.get(film).json()
    film_title = cur_film["title"]
    films.append(film_title)
    
print(f"{character_name} was in:")
print(films)
# Out:
# Darth Vader was in:
# ['A New Hope', 'The Empire Strikes Back', 'Return of the Jedi', 'Revenge of the Sith']

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.05 Partners Do: Number Facts (10 mins)

# %% [markdown]
# * **Instructions:**
#
#   * Using the [Numbers API](http://numbersapi.com), create an application that takes in a user's inputs and returns a number fact based upon it.
#
# * **Hints:**
#
#   * The URL to make your request to must have `?json` at its end so that the data format returned is JSON. The default response is pure text.
#
#   * Make sure to read through the documentation when creating your application. Some types require more or less data than others.

# %%
# Dependencies
import requests
import json

# %%
# Base URL for GET requests to retrieve number/date facts
url = "http://numbersapi.com/"

# %%
# Ask the user what kind of data they would like to search for
question = ("What type of data would you like to search for? "
            "[Trivia, Math, Date, or Year] ")
kind_of_search = input(question)
# Out:
# What type of data would you like to search for? [Trivia, Math, Date, or Year]  Math

# %%
kind_of_search
# Out:
# 'Math'

# %%
# If the kind of search is "date" take in two numbers
if(kind_of_search.lower() == "date"):

  # Collect the month to search for
  month = input("What month would you like to search for? ")
  # Collect the day to search for
  day = input("What day would you like to search for? ")
  number = f"{month}/{day}"

  # Make an API call to the "date" API and convert response object to JSON
  response = requests.get(f"{url}{month}/{day}/{kind_of_search.lower()}?json").json()
  # Print the fact stored within the response
  print(response["text"])

# If the kind of search is anything but "date" then take one number
else:

  # Collect the number to search for
  number = input("What number would you like to search for? ")

  # Make an API call to the API and convert response object to JSON
  response = requests.get(url + number + "/" +  kind_of_search.lower()+ "?json").json()
  # Print the fact stored within the response
  print(response["text"])
# Out:
# What number would you like to search for?  11
# 11 is the 5th smallest prime number.

# %%
url + number + "/" +  kind_of_search.lower()+ "?json"
# Out:
# 'http://numbersapi.com/11/math?json'

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### BREAK (0:10)

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.06 Instructor Do: OMDb API (10 mins)

# %% [markdown]
# ### API Keys:
# * Request free API Key from `OMDBAPI` [Here](https://www.omdbapi.com/apikey.aspx)

# %%
import requests
import json
# from config import omdb_api_key
# omdb_api_key = "TYPE YOUR API KEY HERE"

# %%
# pip install python-dotenv
import os
from dotenv import load_dotenv
load_dotenv()
omdb_api_key = os.getenv("omdb_api_key")

# %%
# New Dependency! Use this to pretty print the JSON
# https://docs.python.org/3/library/pprint.html
from pprint import pprint

# %% [markdown]
# ```
# protocol/Schema = http/https
# [user:pass@]
# domain/hostname/ip
# [:port]
# path
# [?(q=a&)]
# ```

# %%
# Note that the ?t= is a query param for the t-itle of the
# movie we want to search for.
url = "http://www.omdbapi.com/?s="
api_key = "&apikey=" + omdb_api_key

# %%
full_url = url + "Frozen" + api_key
# full_url

# %%
# Performing a GET request similar to the one we executed
# earlier
response = requests.get(full_url)
response
# Out:
# <Response [200]>

# %%
# Converting the response to JSON, and printing the result.
data = response.json()["Search"][0]
print(json.dumps(data, indent=4))
# Out:
# {
#     "Title": "Frozen",
#     "Year": "2013",
#     "imdbID": "tt2294629",
#     "Type": "movie",
#     "Poster": "https://m.media-amazon.com/images/M/MV5BMTQ1MjQwMTE5OF5BMl5BanBnXkFtZTgwNjk3MTcyMDE@._V1_SX300.jpg"
# }

# %%
# Print a few keys from the response JSON.
# print(f"Movie was directed by {data['Director']}.")
print(f"Movie was released in {data['Title']}.")
print(f"Movie was released in {data['Year']}.")
# print(f"Movie was released in {data['Rated']}.")
# print(f"Movie was released in {data['Ratings']}.")
# Out:
# Movie was released in Frozen.
# Movie was released in 2013.

# %%
url = "http://www.omdbapi.com/?apikey=" + omdb_api_key
full_url2 = url+"&i="+data['imdbID']
full_url2
# Out:
# 'http://www.omdbapi.com/?apikey=f36a401e&i=tt2294629'

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.07 Students Do: Study the OMDb API (5 mins)

# %% [markdown]
# * **Instructions:**
#
#   * Read the OMDb documentation, and make a few API calls to
#     get some information about your favorite movie: <http://www.omdbapi.com/>

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.08 Students Do: Movie Questions (10 mins)

# %% [markdown]
# Use the OMDb API to retrieve and print the following information.
#
# * Who was the director of the movie *Aliens*?
#
# * What was the movie *Gladiator* rated?
#
# * What year was *50 First Dates* released?
#
# * Who wrote *Moana*?
#
# * What was the plot of the movie *Sing*?

# %%
# Dependencies
import requests
# from config import omdb_api_key
# omdb_api_key = "TYPE YOUR API KEY HERE"
url = f"http://www.omdbapi.com/?apikey={omdb_api_key}&t="
url
# Out:
# 'http://www.omdbapi.com/?apikey=f36a401e&t='

# %%
# Who was the director of the movie Aliens?
movie = requests.get(url + "Aliens").json()
print(f'The director of Aliens was {movie["Director"]}.')
# Out:
# The director of Aliens was James Cameron.

# %%
# url + "Aliens"

# %%
# What was the movie Gladiator rated?
movie = requests.get(url + "Gladiator").json()
pprint(movie)
print(f'The rating of Gladiator was {movie["Rated"]}.')
# Out:
# {'Actors': 'Russell Crowe, Joaquin Phoenix, Connie Nielsen',
#  'Awards': 'Won 5 Oscars. 60 wins & 106 nominations total',
#  'BoxOffice': '$187,705,427',
#  'Country': 'United States, United Kingdom, Malta, Morocco',
#  'DVD': '26 Sep 2000',
#  'Director': 'Ridley Scott',
#  'Genre': 'Action, Adventure, Drama',
#  'Language': 'English',
#  'Metascore': '67',
#  'Plot': 'A former Roman General sets out to exact vengeance against the '
#          'corrupt emperor who murdered his family and sent him into slavery.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#  'Production': 'N/A',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.5/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '79%'},
#              {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Released': '05 May 2000',
#  'Response': 'True',
#  'Runtime': '155 min',
#  'Title': 'Gladiator',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Franzoni, John Logan, William Nicholson',
#  'Year': '2000',
#  'imdbID': 'tt0172495',
#  'imdbRating': '8.5',
#  'imdbVotes': '1,500,011'}
# The rating of Gladiator was R.

# %%
# What year was 50 First Dates released?
movie = requests.get(url + "50 First Dates").json()
print(f'The movie 50 First Dates was released in {movie["Year"]}.')
# Out:
# The movie 50 First Dates was released in 2004.

# %%
# Who wrote Moana?
movie = requests.get(url + "Moana").json()
print(f'Moana was written by {movie["Writer"]}.')
# Out:
# Moana was written by Jared Bush, Ron Clements, John Musker.

# %%
# What was the plot of the movie Sing?
movie = requests.get(url + "Sing").json()
print(f'The plot of Sing was: {movie["Plot"]}')
# Out:
# The plot of Sing was: In a city of humanoid animals, a hustling theater impresario's attempt to save his theater with a singing competition becomes grander than he anticipates even as its finalists find that their lives will never be the same.

# %%
url = f"http://www.omdbapi.com/?apikey={omdb_api_key}&s=batman"
movie = requests.get(url).json()
movie
# Out:
# {'Search': [{'Title': 'Batman Begins',
#    'Year': '2005',
#    'imdbID': 'tt0372784',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BOTY4YjI2N2MtYmFlMC00ZjcyLTg3YjEtMDQyM2ZjYzQ5YWFkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg'},
#   {'Title': 'Batman v Superman: Dawn of Justice',
#    'Year': '2016',
#    'imdbID': 'tt2975590',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BYThjYzcyYzItNTVjNy00NDk0LTgwMWQtYjMwNmNlNWJhMzMyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg'},
#   {'Title': 'The Batman',
#    'Year': '2022',
#    'imdbID': 'tt1877830',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMDdmMTBiNTYtMDIzNi00NGVlLWIzMDYtZTk3MTQ3NGQxZGEwXkEyXkFqcGdeQXVyMzMwOTU5MDk@._V1_SX300.jpg'},
#   {'Title': 'Batman',
#    'Year': '1989',
#    'imdbID': 'tt0096895',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BZDNjOGNhN2UtNmNhMC00YjU4LWEzMmUtNzRkM2RjN2RiMjc5XkEyXkFqcGdeQXVyMTU0OTM5ODc1._V1_SX300.jpg'},
#   {'Title': 'Batman Returns',
#    'Year': '1992',
#    'imdbID': 'tt0103776',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BOGZmYzVkMmItM2NiOS00MDI3LWI4ZWQtMTg0YWZkODRkMmViXkEyXkFqcGdeQXVyODY0NzcxNw@@._V1_SX300.jpg'},
#   {'Title': 'Batman & Robin',
#    'Year': '1997',
#    'imdbID': 'tt0118688',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMGQ5YTM1NmMtYmIxYy00N2VmLWJhZTYtN2EwYTY3MWFhOTczXkEyXkFqcGdeQXVyNTA2NTI0MTY@._V1_SX300.jpg'},
#   {'Title': 'Batman Forever',
#    'Year': '1995',
#    'imdbID': 'tt0112462',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BNDdjYmFiYWEtYzBhZS00YTZkLWFlODgtY2I5MDE0NzZmMDljXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg'},
#   {'Title': 'The Lego Batman Movie',
#    'Year': '2017',
#    'imdbID': 'tt4116284',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcyNTEyOTY0M15BMl5BanBnXkFtZTgwOTAyNzU3MDI@._V1_SX300.jpg'},
#   {'Title': 'Batman: The Animated Series',
#    'Year': '1992–1995',
#    'imdbID': 'tt0103359',
#    'Type': 'series',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BOTM3MTRkZjQtYjBkMy00YWE1LTkxOTQtNDQyNGY0YjYzNzAzXkEyXkFqcGdeQXVyOTgwMzk1MTA@._V1_SX300.jpg'},
#   {'Title': 'Batman v Superman: Dawn of Justice (Ultimate Edition)',
#    'Year': '2016',
#    'imdbID': 'tt18689424',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BN2I4OTllM2MtMWVhNC00MjkzLWJlMDUtN2FhMGQ2ZGVjMjllXkEyXkFqcGdeQXVyMTEyNzgwMDUw._V1_SX300.jpg'}],
#  'totalResults': '523',
#  'Response': 'True'}

# %%
data = []
for z in range(1,20):
    url = f"http://www.omdbapi.com/?apikey={omdb_api_key}&s=batman&page={z}"
    movie = requests.get(url).json()
    movie
    for x in movie["Search"]:
        data.append([x['Title'], x['Year'], f"https://www.imdb.com/title/{x['imdbID']}"])

# %%
import pandas as pd
df = pd.DataFrame(data, columns=["Title", "Year", "IMDB_Link"])

# %%
df.sort_values("Year", ascending=False)
# Out:
#                                     Title  Year  \
# 2                              The Batman  2022
# 32   Batman: The Long Halloween, Part One  2021
# 73             Batman: The Long Halloween  2021
# 36   Batman: The Long Halloween, Part Two  2021
# 46             Batman: Soul of the Dragon  2021
# ..                                    ...   ...
# 171                 Alyas Batman at Robin  1965
# 142                      Batman and Robin  1964
# 89                         Batman Dracula  1964
# 63                       Batman and Robin  1949
# 59                                 Batman  1943
#
#                                  IMDB_Link
# 2     https://www.imdb.com/title/tt1877830
# 32   https://www.imdb.com/title/tt14324650
# 73   https://www.imdb.com/title/tt21445686
# 36   https://www.imdb.com/title/tt14402926
# 46   https://www.imdb.com/title/tt12885852
# ..                                     ...
# 171   https://www.imdb.com/title/tt1228961
# 142   https://www.imdb.com/title/tt3959414
# 89    https://www.imdb.com/title/tt0057875
# 63    https://www.imdb.com/title/tt0041162
# 59    https://www.imdb.com/title/tt0035665
#
# [190 rows x 3 columns]

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.09 Instructor Do: Iterative Requests (5 mins)

# %%
# Dependencies
import random
import json
import requests

# %%
# Let's get the JSON for 100 posts sequentially.
url = "http://jsonplaceholder.typicode.com/posts/"

# %%
# Create an empty list to store the responses
response_json = []

# %%
# Create random indices representing
# a user's choice of posts
indices = random.sample(list(range(1, 100)), 5)
indices
# Out:
# [64, 95, 86, 84, 72]

# %%
# Make a request for each of the indices
for x in range(len(indices)):
    print(f"Making request number: {x} for ID: {indices[x]}")

    # Get one of the posts
    post_response = requests.get(url + str(indices[x]))

    # Save post's JSON
    response_json.append(post_response.json())
# Out:
# Making request number: 0 for ID: 64
# Making request number: 1 for ID: 95
# Making request number: 2 for ID: 86
# Making request number: 3 for ID: 84
# Making request number: 4 for ID: 72

# %%
# Now we have 10 post objects, 
# which we got by making 100 requests to the API.
print(f"We have {len(response_json)} posts!")
# Out:
# We have 5 posts!

# %%
response_json
# Out:
# [{'userId': 7,
#   'id': 64,
#   'title': 'et fugit quas eum in in aperiam quod',
#   'body': 'id velit blanditiis\neum ea voluptatem\nmolestiae sint occaecati est eos perspiciatis\nincidunt a error provident eaque aut aut qui'},
#  {'userId': 10,
#   'id': 95,
#   'title': 'id minus libero illum nam ad officiis',
#   'body': 'earum voluptatem facere provident blanditiis velit laboriosam\npariatur accusamus odio saepe\ncumque dolor qui a dicta ab doloribus consequatur omnis\ncorporis cupiditate eaque assumenda ad nesciunt'},
#  {'userId': 9,
#   'id': 86,
#   'title': 'placeat quia et porro iste',
#   'body': 'quasi excepturi consequatur iste autem temporibus sed molestiae beatae\net quaerat et esse ut\nvoluptatem occaecati et vel explicabo autem\nasperiores pariatur deserunt optio'},
#  {'userId': 9,
#   'id': 84,
#   'title': 'optio ipsam molestias necessitatibus occaecati facilis veritatis dolores aut',
#   'body': 'sint molestiae magni a et quos\neaque et quasi\nut rerum debitis similique veniam\nrecusandae dignissimos dolor incidunt consequatur odio'},
#  {'userId': 8,
#   'id': 72,
#   'title': 'sint hic doloribus consequatur eos non id',
#   'body': 'quam occaecati qui deleniti consectetur\nconsequatur aut facere quas exercitationem aliquam hic voluptas\nneque id sunt ut aut accusamus\nsunt consectetur expedita inventore velit'}]

# %%
print(json.dumps(response_json, indent=4, sort_keys=True))

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.10 Students Do: Iterative Requests (10 mins)

# %% [markdown]
# # Instructions
#
# Consider the following list of movie titles.
#
# ```python
# movies = ["Aliens", "Sing", "Moana"]
# ```
#
# Make a request to the OMDb API for each movie in the list. Then:
#
# 1. Print the director of each movie
#
# 2. Save the responses in another list

# %%
# Dependencies
import requests
# from config import omdb_api_key
omdb_api_key = "f36a401e"
# omdb_api_key = "TYPE YOUR API KEY HERE"

# %%
url = "http://www.omdbapi.com/?apikey=" + omdb_api_key + "&t="
movies = ["Aliens", "Sing", "Moana"]
for x in movies:
    movie_data = requests.get(url + x).json()
    print(movie_data["Rated"])
# Out:
# R
# PG
# PG

# %%
# YOUR CODE HERE
url = "http://www.omdbapi.com/?apikey=" + omdb_api_key + "&t="

movies = ["Aliens", "Sing", "Moana"]

responses = []

for movie in movies:
    movie_data = requests.get(url + movie).json()
    responses.append(movie_data)
    print(f'The director of {movie} is {movie_data["Director"]}')
# Out:
# The director of Aliens is James Cameron
# The director of Sing is Garth Jennings, Christophe Lourdelet
# The director of Moana is Ron Clements, John Musker, Don Hall

# %%
responses
# Out:
# [{'Title': 'Aliens',
#   'Year': '1986',
#   'Rated': 'R',
#   'Released': '18 Jul 1986',
#   'Runtime': '137 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'Director': 'James Cameron',
#   'Writer': 'James Cameron, David Giler, Walter Hill',
#   'Actors': 'Sigourney Weaver, Michael Biehn, Carrie Henn',
#   'Plot': 'Fifty-seven years after surviving an apocalyptic attack aboard her space vessel by merciless space creatures, Officer Ripley awakens from hyper-sleep and tries to warn anyone who will listen about the predators.',
#   'Language': 'English, Spanish',
#   'Country': 'United Kingdom, United States',
#   'Awards': 'Won 2 Oscars. 20 wins & 23 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYjE1ZDgxMTMtYzA3Ny00MjIwLWFiZTUtZDhhMjM3YzA3M2RkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.4/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '98%'},
#    {'Source': 'Metacritic', 'Value': '84/100'}],
#   'Metascore': '84',
#   'imdbRating': '8.4',
#   'imdbVotes': '719,280',
#   'imdbID': 'tt0090605',
#   'Type': 'movie',
#   'DVD': '01 Jun 1999',
#   'BoxOffice': '$85,160,248',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Sing',
#   'Year': '2016',
#   'Rated': 'PG',
#   'Released': '21 Dec 2016',
#   'Runtime': '108 min',
#   'Genre': 'Animation, Comedy, Family',
#   'Director': 'Garth Jennings, Christophe Lourdelet',
#   'Writer': 'Garth Jennings',
#   'Actors': 'Matthew McConaughey, Reese Witherspoon, Seth MacFarlane',
#   'Plot': "In a city of humanoid animals, a hustling theater impresario's attempt to save his theater with a singing competition becomes grander than he anticipates even as its finalists find that their lives will never be the same.",
#   'Language': 'Japanese, Ukrainian, Persian, English',
#   'Country': 'Japan, United States, France',
#   'Awards': '3 wins & 25 nominations',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzODYzODU2Ml5BMl5BanBnXkFtZTgwNTc1MTA2NzE@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.1/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
#    {'Source': 'Metacritic', 'Value': '59/100'}],
#   'Metascore': '59',
#   'imdbRating': '7.1',
#   'imdbVotes': '172,476',
#   'imdbID': 'tt3470600',
#   'Type': 'movie',
#   'DVD': '18 Apr 2017',
#   'BoxOffice': '$270,578,425',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'},
#  {'Title': 'Moana',
#   'Year': '2016',
#   'Rated': 'PG',
#   'Released': '23 Nov 2016',
#   'Runtime': '107 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'Director': 'Ron Clements, John Musker, Don Hall',
#   'Writer': 'Jared Bush, Ron Clements, John Musker',
#   'Actors': "Auli'i Cravalho, Dwayne Johnson, Rachel House",
#   'Plot': "In Ancient Polynesia, when a terrible curse incurred by the Demigod Maui reaches Moana's island, she answers the Ocean's call to seek out the Demigod to set things right.",
#   'Language': 'English, French',
#   'Country': 'United States',
#   'Awards': 'Nominated for 2 Oscars. 21 wins & 90 nominations total',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI4MzU5NTExNF5BMl5BanBnXkFtZTgwNzY1MTEwMDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#    {'Source': 'Metacritic', 'Value': '81/100'}],
#   'Metascore': '81',
#   'imdbRating': '7.6',
#   'imdbVotes': '337,620',
#   'imdbID': 'tt3521164',
#   'Type': 'movie',
#   'DVD': '07 Mar 2017',
#   'BoxOffice': '$248,757,044',
#   'Production': 'N/A',
#   'Website': 'N/A',
#   'Response': 'True'}]

# %%
print(json.dumps(responses, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "Actors": "Sigourney Weaver, Michael Biehn, Carrie Henn",
#         "Awards": "Won 2 Oscars. 20 wins & 23 nominations total",
#         "BoxOffice": "$85,160,248",
#         "Country": "United Kingdom, United States",
#         "DVD": "01 Jun 1999",
#         "Director": "James Cameron",
#         "Genre": "Action, Adventure, Sci-Fi",
#         "Language": "English, Spanish",
#         "Metascore": "84",
#         "Plot": "Fifty-seven years after surviving an apocalyptic attack aboard her space vessel by merciless space creatures, Officer Ripley awakens from hyper-sleep and tries to warn anyone who will listen about the predators.",
#         "Poster": "https://m.media-amazon.com/images/M/MV5BYjE1ZDgxMTMtYzA3Ny00MjIwLWFiZTUtZDhhMjM3YzA3M2RkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg",
#         "Production": "N/A",
#         "Rated": "R",
#         "Ratings": [
#             {
#                 "Source": "Internet Movie Database",
#                 "Value": "8.4/10"
#             },
#             {
#                 "Source": "Rotten Tomatoes",
#                 "Value": "98%"
#             },
#             {
#                 "Source": "Metacritic",
#                 "Value": "84/100"
#             }
#         ],
#         "Released": "18 Jul 1986",
#         "Response": "True",
#         "Runtime": "137 min",
#         "Title": "Aliens",
#         "Type": "movie",
#         "Website": "N/A",
#         "Writer": "James Cameron, David Giler, Walter Hill",
#         "Year": "1986",
#         "imdbID": "tt0090605",
#         "imdbRating": "8.4",
#         "imdbVotes": "719,280"
#     },
#     {
#         "Actors": "Matthew McConaughey, Reese Witherspoon, Seth MacFarlane",
#         "Awards": "3 wins & 25 nominations",
#         "BoxOffice": "$270,578,425",
#         "Country": "Japan, United States, France",
#         "DVD": "18 Apr 2017",
#         "Director": "Garth Jennings, Christophe Lourdelet",
#         "Genre": "Animation, Comedy, Family",
#         "Language": "Japanese, Ukrainian, Persian, English",
#         "Metascore": "59",
#         "Plot": "In a city of humanoid animals, a hustling theater impresario's attempt to save his theater with a singing competition becomes grander than he anticipates even as its finalists find that their lives will never be the same.",
#         "Poster": "https://m.media-amazon.com/images/M/MV5BMTYzODYzODU2Ml5BMl5BanBnXkFtZTgwNTc1MTA2NzE@._V1_SX300.jpg",
#         "Production": "N/A",
#         "Rated": "PG",
#         "Ratings": [
#             {
#                 "Source": "Internet Movie Database",
#                 "Value": "7.1/10"
#             },
#             {
#                 "Source": "Rotten Tomatoes",
#                 "Value": "71%"
#             },
#             {
#                 "Source": "Metacritic",
#                 "Value": "59/100"
#             }
#         ],
#         "Released": "21 Dec 2016",
#         "Response": "True",
#         "Runtime": "108 min",
#         "Title": "Sing",
#         "Type": "movie",
#         "Website": "N/A",
#         "Writer": "Garth Jennings",
#         "Year": "2016",
#         "imdbID": "tt3470600",
#         "imdbRating": "7.1",
#         "imdbVotes": "172,476"
#     },
#     {
#         "Actors": "Auli'i Cravalho, Dwayne Johnson, Rachel House",
#         "Awards": "Nominated for 2 Oscars. 21 wins & 90 nominations total",
#         "BoxOffice": "$248,757,044",
#         "Country": "United States",
#         "DVD": "07 Mar 2017",
#         "Director": "Ron Clements, John Musker, Don Hall",
#         "Genre": "Animation, Adventure, Comedy",
#         "Language": "English, French",
#         "Metascore": "81",
#         "Plot": "In Ancient Polynesia, when a terrible curse incurred by the Demigod Maui reaches Moana's island, she answers the Ocean's call to seek out the Demigod to set things right.",
#         "Poster": "https://m.media-amazon.com/images/M/MV5BMjI4MzU5NTExNF5BMl5BanBnXkFtZTgwNzY1MTEwMDI@._V1_SX300.jpg",
#         "Production": "N/A",
#         "Rated": "PG",
#         "Ratings": [
#             {
#                 "Source": "Internet Movie Database",
#                 "Value": "7.6/10"
#             },
#             {
#                 "Source": "Rotten Tomatoes",
#                 "Value": "95%"
#             },
#             {
#                 "Source": "Metacritic",
#                 "Value": "81/100"
#             }
#         ],
#         "Released": "23 Nov 2016",
#         "Response": "True",
#         "Runtime": "107 min",
#         "Title": "Moana",
#         "Type": "movie",
#         "Website": "N/A",
#         "Writer": "Jared Bush, Ron Clements, John Musker",
#         "Year": "2016",
#         "imdbID": "tt3521164",
#         "imdbRating": "7.6",
#         "imdbVotes": "337,620"
#     }
# ]

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.11 Instructor Do: NYT API (5 mins)

# %% [markdown]
# * First create an account with NYT by filling out this [form](https://developer.nytimes.com/accounts/create).
#
#   ![NYT Create Account](../Images/11-NYT_account.png)
#
#   * Navigate to the index of the email used to sign-up and activate the account.
#
#   * **Note:** Make sure to check your spam folder for the email from New York Times article API.
#   * Navigate back the [sign in page](https://developer.nytimes.com/accounts/login) and login with the newly created account.
#
# * Once you have successfully made a NYT account and logged in, it's time to create an app and obtain an API KEY.
#
#   * From the drop down on the top right next to your email, click on apps.
#
#   ![select apps](../Images/11-select_apps.png)
#
#   * Click on **+NEW APP**.
#
#   * This will bring you to app creation page. Give the app any name.
#
#   ![Name app](../Images/11-NYT_name_app.png)
#
#   * Scroll down to the **Article Search API** and select it.
#
#   ![Article API](../Images/11-article_api.png)
#
#   * Scroll back up to the top and click **CREATE**.
#
# * After the app is created, you will be re-directed to the app page, which contains the API key. you will use this key to interact with the NYT API.
#
#   ![NYT API Key](../Images/11-NYT_api_key.png)

# %%
# Dependencies
import requests
from pprint import pprint
# from config import nyt_api_key
nyt_api_key = "fvAG7OyUfSzjkrWifbGgAIG374piUiJN"
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention granola
query = "world cup"
# query = "election"

# %%
# Build query URL
query_url = url + "api-key=" + nyt_api_key + "&q=" + query

# %%
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=fvAG7OyUfSzjkrWifbGgAIG374piUiJN&q=world cup

# %%
# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = articles["response"]["docs"]
pprint(articles_list)
# Out:
# [{'_id': 'nyt://article/32f0f746-e993-5680-920f-f703a067cec6',
#   'abstract': 'The “potrero” circuit around Buenos Aires recalls the game’s '
#               'early, rawer beginnings with a gifted style of play the country '
#               'has become known for.',
#   'byline': {'organization': None,
#              'original': 'By Juan José Relmucao and Anita Pouchard Serra',
#              'person': [{'firstname': 'Juan',
#                          'lastname': 'Relmucao',
#                          'middlename': 'José',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Anita',
#                          'lastname': 'Serra',
#                          'middlename': 'Pouchard',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Far From the World Cup, the Essence of Argentine '
#                        'Soccer Expands Its Reach',
#                'name': None,
#                'print_headline': 'Far From Qatar,  A Game Thrives  In the '
#                                  'Barrios',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Soccer'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'World Cup 2022 (Soccer)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 3,
#                 'value': 'Buenos Aires (Argentina)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 4,
#                 'value': 'ARGENTINA'}],
#   'lead_paragraph': 'BUENOS AIRES — The essence of Argentine soccer can be '
#                     'found late at night, in the circuit of games in barrios '
#                     'outside Buenos Aires.',
#   'multimedia': [],
#   'news_desk': 'Sports',
#   'print_page': '6',
#   'print_section': 'B',
#   'pub_date': '2022-12-27T10:00:43+0000',
#   'section_name': 'Sports',
#   'snippet': 'The “potrero” circuit around Buenos Aires recalls the game’s '
#              'early, rawer beginnings with a gifted style of play the country '
#              'has become known for.',
#   'source': 'The New York Times',
#   'subsection_name': 'Soccer',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/32f0f746-e993-5680-920f-f703a067cec6',
#   'web_url': 'https://www.nytimes.com/2022/12/27/sports/soccer/world-cup-argentina-street-soccer.html',
#   'word_count': 911},
#  {'_id': 'nyt://article/a9bb6a01-36e7-5a69-b5a9-47611e5b6425',
#   'abstract': 'An autopsy in New York showed that the journalist had a tear in '
#               'the ascending aorta, a large vessel that carries blood from the '
#               'heart.',
#   'byline': {'organization': None,
#              'original': 'By Apoorva Mandavilli and Andrew Das',
#              'person': [{'firstname': 'Apoorva',
#                          'lastname': 'Mandavilli',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Andrew',
#                          'lastname': 'Das',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Grant Wahl Died of a Burst Blood Vessel, His Family '
#                        'Says',
#                'name': None,
#                'print_headline': 'Wahl’s Death Caused By Burst Blood Vessel; '
#                                  'Foul Play Is Ruled Out',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'your-feed-science'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 2,
#                 'value': 'Wahl, Grant (1974-2022)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Deaths (Fatalities)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'News and News Media'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 5,
#                 'value': 'Aneurysms'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 6,
#                 'value': 'Autopsies'},
#                {'major': 'N', 'name': 'subject', 'rank': 7, 'value': 'AORTA'},
#                {'major': 'N', 'name': 'subject', 'rank': 8, 'value': 'Soccer'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 9,
#                 'value': 'World Cup 2022 (Soccer)'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 10,
#                 'value': 'Sports Illustrated'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 11,
#                 'value': 'Gounder, Celine'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 12,
#                 'value': 'Qatar'}],
#   'lead_paragraph': 'Grant Wahl, the celebrated soccer journalist who died '
#                     'suddenly last week at the World Cup in Qatar, had a '
#                     'rupture in a blood vessel leading from the heart, his '
#                     'family announced on Wednesday.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 400,
#                   'legacy': {'xlarge': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-articleLarge.jpg',
#                              'xlargeheight': 400,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 433,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-popup.jpg',
#                   'width': 650},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 355,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 285,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 241,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 395,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 400,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-slide.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 683,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-jumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 1365,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-superJumbo.jpg',
#                   'width': 2048},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 700,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-master1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 450,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-master675.jpg',
#                   'width': 675},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 330,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-master495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 120,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
#                   'subtype': 'master180',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-master180.jpg',
#                   'width': 180},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master315',
#                   'height': 210,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master315',
#                   'subtype': 'master315',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-master315.jpg',
#                   'width': 315},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master768',
#                   'height': 512,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master768',
#                   'subtype': 'master768',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-master768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-blogSmallThumb.jpg',
#                   'width': 50},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbLarge',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'thumbLarge',
#                   'subtype': 'thumbLarge',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-thumbLarge.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare168',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare168',
#                   'subtype': 'smallSquare168',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-smallSquare168.jpg',
#                   'width': 168},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare252',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare252',
#                   'subtype': 'smallSquare252',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-smallSquare252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square320',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square320',
#                   'subtype': 'square320',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-square320.jpg',
#                   'width': 320},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'moth',
#                   'height': 151,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'moth',
#                   'subtype': 'moth',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-moth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'filmstrip',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'filmstrip',
#                   'subtype': 'filmstrip',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-filmstrip.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square640',
#                   'height': 640,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square640',
#                   'subtype': 'square640',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-square640.jpg',
#                   'width': 640},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquare149',
#                   'height': 149,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquare149',
#                   'subtype': 'mediumSquare149',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumSquare149.jpg',
#                   'width': 149},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquareAt3X',
#                   'height': 1800,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquareAt3X',
#                   'subtype': 'mediumSquareAt3X',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumSquareAt3X.jpg',
#                   'width': 1800},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'sfSpan',
#                   'height': 263,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'sfSpan',
#                   'subtype': 'sfSpan',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-sfSpan.jpg',
#                   'width': 395},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontal375',
#                   'height': 250,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontal375',
#                   'subtype': 'largeHorizontal375',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-largeHorizontal375.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontalJumbo',
#                   'height': 683,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontalJumbo',
#                   'subtype': 'largeHorizontalJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-largeHorizontalJumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'horizontalMediumAt2X',
#                   'height': 3300,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'horizontalMediumAt2X',
#                   'subtype': 'horizontalMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-horizontalMediumAt2X.jpg',
#                   'width': 4951},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpLarge',
#                   'height': 287,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpLarge',
#                   'subtype': 'hpLarge',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-hpLarge.jpg',
#                   'width': 511},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen573',
#                   'height': 322,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen573',
#                   'subtype': 'largeWidescreen573',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-largeWidescreen573.jpg',
#                   'width': 573},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen1050',
#                   'height': 590,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen1050',
#                   'subtype': 'largeWidescreen1050',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-largeWidescreen1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbWide',
#                   'height': 126,
#                   'legacy': {'wide': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-thumbWide.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subType': 'wide',
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-thumbWide.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoThumb',
#                   'subtype': 'videoThumb',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoThumb.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoLarge',
#                   'height': 507,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoLarge',
#                   'subtype': 'videoLarge',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoLarge.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo210',
#                   'height': 140,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo210',
#                   'subtype': 'mediumThreeByTwo210',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumThreeByTwo210.jpg',
#                   'width': 210},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo225',
#                   'subtype': 'mediumThreeByTwo225',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumThreeByTwo225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo440',
#                   'height': 293,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo440',
#                   'subtype': 'mediumThreeByTwo440',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumThreeByTwo440.jpg',
#                   'width': 440},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo252',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo252',
#                   'subtype': 'mediumThreeByTwo252',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumThreeByTwo252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo378',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo378',
#                   'subtype': 'mediumThreeByTwo378',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumThreeByTwo378.jpg',
#                   'width': 378},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoLargeAt2X',
#                   'height': 3048,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoLargeAt2X',
#                   'subtype': 'threeByTwoLargeAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-threeByTwoLargeAt2X.jpg',
#                   'width': 4572},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoMediumAt2X',
#                   'height': 1000,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoMediumAt2X',
#                   'subtype': 'threeByTwoMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-threeByTwoMediumAt2X.jpg',
#                   'width': 1500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoSmallAt2X',
#                   'height': 400,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoSmallAt2X',
#                   'subtype': 'threeByTwoSmallAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-threeByTwoSmallAt2X.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 131,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-articleInline.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpSmall',
#                   'height': 113,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpSmall',
#                   'subtype': 'hpSmall',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-hpSmall.jpg',
#                   'width': 163},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 104,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 122,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mediumFlexible177.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSmall.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 211,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoHpMedium.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine600',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine600',
#                   'subtype': 'videoSixteenByNine600',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine600.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine540',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine540',
#                   'subtype': 'videoSixteenByNine540',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine540.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine390.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine310.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine96.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine3000',
#                   'height': 1687,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine3000',
#                   'subtype': 'videoSixteenByNine3000',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine3000.jpg',
#                   'width': 3000},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNine150.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 900,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoSixteenByNineJumbo1600.jpg',
#                   'width': 1600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'miniMoth',
#                   'height': 70,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'miniMoth',
#                   'subtype': 'miniMoth',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-miniMoth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-windowsTile336H.jpg',
#                   'width': 694},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven1305',
#                   'height': 609,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven1305',
#                   'subtype': 'videoFifteenBySeven1305',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoFifteenBySeven1305.jpg',
#                   'width': 1305},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven2610',
#                   'height': 1218,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven2610',
#                   'subtype': 'videoFifteenBySeven2610',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-videoFifteenBySeven2610.jpg',
#                   'width': 2610},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 549,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-facebookJumbo.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-watch308.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 303,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-watch268.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'verticalTwoByThree735',
#                   'height': 1103,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'verticalTwoByThree735',
#                   'subtype': 'verticalTwoByThree735',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-verticalTwoByThree735.jpg',
#                   'width': 735},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mobileMasterAt3x',
#                   'height': 1200,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mobileMasterAt3x',
#                   'subtype': 'mobileMasterAt3x',
#                   'type': 'image',
#                   'url': 'images/2022/12/14/science/14wahl-death1/14wahl-death1-mobileMasterAt3x.jpg',
#                   'width': 1800}],
#   'news_desk': 'Science',
#   'print_page': '10',
#   'print_section': 'B',
#   'pub_date': '2022-12-14T13:23:16+0000',
#   'section_name': 'Health',
#   'snippet': 'An autopsy in New York showed that the journalist had a tear in '
#              'the ascending aorta, a large vessel that carries blood from the '
#              'heart.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/a9bb6a01-36e7-5a69-b5a9-47611e5b6425',
#   'web_url': 'https://www.nytimes.com/2022/12/14/health/grant-wahl-death.html',
#   'word_count': 819},
#  {'_id': 'nyt://article/0eef14ea-4099-51dc-a930-996edb68ca3b',
#   'abstract': 'Our photographers in Qatar show what the world’s biggest soccer '
#               'tournament looks like from the streets of Doha and beyond.',
#   'byline': {'organization': None,
#              'original': 'By Erin Schaff and Tasneem Alsultan',
#              'person': [{'firstname': 'Erin',
#                          'lastname': 'Schaff',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Tasneem',
#                          'lastname': 'Alsultan',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Watching Qatar’s World Cup, Off the Field',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'World Cup 2022 (Soccer)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 2,
#                 'value': 'Qatar'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Photography'}],
#   'lead_paragraph': 'Follow live coverage of the Argentina vs. France World '
#                     'Cup final.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 400,
#                   'legacy': {'xlarge': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-articleLarge.jpg',
#                              'xlargeheight': 400,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 433,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-popup.jpg',
#                   'width': 650},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 355,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 285,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 241,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 395,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2022/11/30/multimedia/30worldcup-photos-EDIT2-1-dbf5/30worldcup-photos-EDIT2-1-dbf5-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
# ...
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine540-v2.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine495-v2.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine390-v2.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine1050-v2.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine480-v2.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine310-v2.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine225-v2.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine96-v2.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine768-v2.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNine150-v2.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 900,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoSixteenByNineJumbo1600-v2.jpg',
#                   'width': 1600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'miniMoth',
#                   'height': 70,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'miniMoth',
#                   'subtype': 'miniMoth',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-miniMoth-v2.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-windowsTile336H-v2.jpg',
#                   'width': 694},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven1305',
#                   'height': 609,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven1305',
#                   'subtype': 'videoFifteenBySeven1305',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoFifteenBySeven1305-v2.jpg',
#                   'width': 1305},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven2610',
#                   'height': 1218,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven2610',
#                   'subtype': 'videoFifteenBySeven2610',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-videoFifteenBySeven2610-v2.jpg',
#                   'width': 2610},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 549,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-facebookJumbo-v2.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-watch308.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 303,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-watch268.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'verticalTwoByThree735',
#                   'height': 1103,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'verticalTwoByThree735',
#                   'subtype': 'verticalTwoByThree735',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-verticalTwoByThree735.jpg',
#                   'width': 735},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mobileMasterAt3x',
#                   'height': 1199,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mobileMasterAt3x',
#                   'subtype': 'mobileMasterAt3x',
#                   'type': 'image',
#                   'url': 'images/2022/11/29/multimedia/29world-cup-usa-wins-1-418c/29world-cup-usa-wins-1-418c-mobileMasterAt3x.jpg',
#                   'width': 1800}],
#   'news_desk': 'Sports',
#   'print_page': '7',
#   'print_section': 'B',
#   'pub_date': '2022-11-29T23:34:04+0000',
#   'section_name': 'Sports',
#   'snippet': 'By toppling Wales, England advanced to the knockout stages, and '
#              'reinvigorated itself.',
#   'source': 'The New York Times',
#   'subsection_name': 'World Cup',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/cb60030a-254e-5849-92be-55a51f1c2a8d',
#   'web_url': 'https://www.nytimes.com/2022/11/29/sports/world-cup/england-wales-win-world-cup.html',
#   'word_count': 479},
#  {'_id': 'nyt://interactive/847fa169-c4e0-55cf-842b-e946053fd224',
#   'abstract': 'See the key play where the Americans scored the opening goal in '
#               'their 1-1 draw with Wales.',
#   'byline': {'organization': None,
#              'original': 'By Chloé Desaulles, Alexandre Devaux, Or Fleisher, '
#                          'Malika Khurana, Allison McCann, Mark McKeague, Scott '
#                          'Reinhard and Bedel Saget',
#              'person': [{'firstname': 'Chloé',
#                          'lastname': 'Desaulles',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Alexandre',
#                          'lastname': 'Devaux',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Or',
#                          'lastname': 'Fleisher',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 3,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Malika',
#                          'lastname': 'Khurana',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 4,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Allison',
#                          'lastname': 'McCann',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 5,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Mark',
#                          'lastname': 'McKeague',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 6,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Scott',
#                          'lastname': 'Reinhard',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 7,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Bedel',
#                          'lastname': 'Saget',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 8,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'multimedia',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'How Pulisic Crafted the U.S. Goal in Its World Cup '
#                        'Opener',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'World Cup 2022 (Soccer)'},
#                {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Soccer'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 3,
#                 'value': 'United States'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 4,
#                 'value': 'Wales'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 5,
#                 'value': 'Pulisic, Christian (1998- )'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 6,
#                 'value': "United States Men's National Soccer Team"},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 7,
#                 'value': 'Weah, Timothy (2000- )'}],
#   'lead_paragraph': 'See the key play where the Americans scored the opening '
#                     'goal in their 1-1 draw with Wales.',
#   'multimedia': [],
#   'news_desk': 'Graphics',
#   'pub_date': '2022-11-22T03:50:26+0000',
#   'section_name': 'Sports',
#   'snippet': 'See the key play where the Americans scored the opening goal in '
#              'their 1-1 draw with Wales.',
#   'source': 'The New York Times',
#   'subsection_name': 'World Cup',
#   'type_of_material': 'Interactive Feature',
#   'uri': 'nyt://interactive/847fa169-c4e0-55cf-842b-e946053fd224',
#   'web_url': 'https://www.nytimes.com/interactive/2022/11/21/sports/world-cup/wales-usmnt-world-cup-goal-pulisic.html',
#   'word_count': 0}]

# %%
len(articles_list)
# Out:
# 10

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print("-"* 32)
    # print(article["headline"])
    if article["headline"]["print_headline"]!= None:
        print(article["headline"]["print_headline"], article["web_url"])
    else:
        print(article["headline"]["main"], article["web_url"])
# Out:
# Your Reading List
# --------------------------------
# Far From Qatar,  A Game Thrives  In the Barrios https://www.nytimes.com/2022/12/27/sports/soccer/world-cup-argentina-street-soccer.html
# --------------------------------
# Wahl’s Death Caused By Burst Blood Vessel; Foul Play Is Ruled Out https://www.nytimes.com/2022/12/14/health/grant-wahl-death.html
# --------------------------------
# Watching Qatar’s World Cup, Off the Field https://www.nytimes.com/2022/12/01/sports/soccer/qatar-world-cup-photos.html
# --------------------------------
# 2022 World Cup Bracket: The Knockout Stage https://www.nytimes.com/interactive/2022/sports/world-cup/world-cup-bracket.html
# --------------------------------
# Germany’s Late Equalizer Revives Its World Cup Hopes https://www.nytimes.com/interactive/2022/11/27/sports/world-cup/spain-germany-world-cup-goal.html
# --------------------------------
# Can You Tell a Country by Its Corner Kicks? https://www.nytimes.com/interactive/2022/12/05/sports/world-cup/corner-kicks-world-cup.html
# --------------------------------
# Richarlison, Messi and Pulisic: Three Stunning Goals Frozen in Time https://www.nytimes.com/interactive/2022/12/03/sports/world-cup/richarlison-messi-pulisic-world-cup-goals.html
# --------------------------------
# Watch Christian Pulisic Send the U.S. Past Iran and Into the Knockout Rounds https://www.nytimes.com/interactive/2022/11/29/sports/world-cup/iran-usa-world-cup-goal-pulisic.html
# --------------------------------
# England Rises, and Looks Formidable Again https://www.nytimes.com/2022/11/29/sports/world-cup/england-wales-win-world-cup.html
# --------------------------------
# How Pulisic Crafted the U.S. Goal in Its World Cup Opener https://www.nytimes.com/interactive/2022/11/21/sports/world-cup/wales-usmnt-world-cup-goal-pulisic.html

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### 1.12 Students Do: Retrieving Articles (20 ins)

# %% [markdown]
# # Instructions
#
# * Save the NYT API endpoint to a variable. Make sure you include the right query parameter to retrieve JSON data!
#
# * Register for and save your API Key to a variable.
#
# * Decide on a search term, and save it to a variable.
#
# * Limit your search to articles published within a range of dates—for example, only articles published in 2014. _Hint_: Read the documentation on `end_date`.
#
# * Build your query URL, and save it to a variable.
#
# * Retrieve a response from the NYT API with a GET request.
#
# * Take a look at the documentation. How do you get a hold of the articles in the response?
#
# * Traverse through the returned JSON to retrieve the list of articles and store it in a variable.
#
# * Print a `snippet` from each article and separate using dashes (`-`).
#
# * As a bonus, try to figure out how we could get 30 results. _Hint_: Look up the `page` query parameter. If you get a message saying you've exceeded your rate limit, don't fret—you've solved the problem.
#
# * **Warning:** Be sure not to print out any of the query URLs. The query URLs will include your API key and if pushed to a public repository, it becomes a security risk for you as someone could steal and use your key.

# %%
# Dependencies
import requests
# from config import nyt_api_key
nyt_api_key = "TYPE YOUR API KEY HERE"
import time

# %%
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = "texas"

# Search for articles published between a begin and end date
begin_date = "20160101"
end_date = "20160130"

query_url = f"{url}api-key={nyt_api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
query_url

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]

for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]}')
    print('---------------------------')

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Empty list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 8):
    query_url = f"{url}api-key={nyt_api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
# query_url

# %%
for article in articles_list:
    print(article['snippet'])
    print('---------------------------')

# %% [markdown]
# # ==========================================

# %% [markdown]
# ### Rating Class Objectives
#
# * rate your understanding using 1-5 method in each objective

# %%
title = "06-Python-APIs - Day 1 - APIs"
objectives = [
    "Make GET requests with the `requests` Library",
    "Manipulate JSON response to retrieve necessary values",
    "Store JSON response in python lists and dictionaries",
    "Identify and generate the type of request needed to request movies by leveraging the OMDB API documentation",
]
rating = []
total = 0
for i in range(len(objectives)):
    rate = input(objectives[i]+"? ")
    total += int(rate)
    rating.append(objectives[i] + ". (" + rate + "/5)")
print("="*96)
print(f"Self Evaluation for: {title}")
print("-"*24)
for i in rating:
    print(i)
print("-"*64)
print("Average: " + str(total/len(objectives)))
